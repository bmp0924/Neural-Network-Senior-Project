# %%
import numpy as np
import os
from os.path import isfile
import keras
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Bidirectional, LSTM, Dropout, Activation, GRU
from keras.layers import Conv2D, concatenate, MaxPooling2D, Flatten, Embedding, Lambda


from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau
from keras import backend as K
from keras.utils import np_utils
from keras.optimizers import Adam, RMSprop

from keras import regularizers


import librosa
import librosa.display
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Load training and Validation arrays

# %%
dict_genres = {'Electronic':0, 'Experimental':1, 'Folk':2, 'Hip-Hop':3, 
               'Instrumental':4,'International':5, 'Pop' :6, 'Rock': 7  }


reverse_map = {v: k for k, v in dict_genres.items()}
print(reverse_map)
# Out:
# {0: 'Electronic', 1: 'Experimental', 2: 'Folk', 3: 'Hip-Hop', 4: 'Instrumental', 5: 'International', 6: 'Pop', 7: 'Rock'}

# %%
npzfile = np.load('shuffled_train.npz')
print(npzfile.files)
X_train = npzfile['arr_0']
y_train = npzfile['arr_1']
print(X_train.shape, y_train.shape)
# Out:
# ['arr_0', 'arr_1']
# (6394, 640, 128) (6394,)

# %%
npzfile = np.load('shuffled_valid.npz')
print(npzfile.files)
X_valid = npzfile['arr_0']
y_valid = npzfile['arr_1']
print(X_valid.shape, y_valid.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %% [markdown]
# ### Check by plotting a Spectogram

# %%
num = 5300
spectogram = X_train[num]
genre = np.argmax(y_train[num])
print(reverse_map[genre])
plt.figure(figsize=(10, 5))
librosa.display.specshow(spectogram.T, y_axis='mel', x_axis='time')
plt.colorbar(format='%+2.0f dB')
plt.title('Test Melspectogram'+' of '+reverse_map[genre]+' Genre')
plt.tight_layout()
# Out:
# Electronic

# %% [markdown]
# ### Parallel CNN - RNN Model

# %%
batch_size = 32
num_classes = 8
n_features = X_train.shape[2]
n_time = X_train.shape[1]

# %%
nb_filters1=16 
nb_filters2=32 
nb_filters3=64
nb_filters4=64
nb_filters5=64
ksize = (3,1)
pool_size_1= (2,2) 
pool_size_2= (4,4)
pool_size_3 = (4,2)

dropout_prob = 0.20
dense_size1 = 128
lstm_count = 64
num_units = 120

BATCH_SIZE = 64
EPOCH_COUNT = 50
L2_regularization = 0.001

def conv_recurrent_model_build(model_input):
    print('Building model...')
    layer = model_input
    
    ### Convolutional blocks
    conv_1 = Conv2D(filters = nb_filters1, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_1')(layer)
    pool_1 = MaxPooling2D(pool_size_1)(conv_1)

    conv_2 = Conv2D(filters = nb_filters2, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_2')(pool_1)
    pool_2 = MaxPooling2D(pool_size_1)(conv_2)

    conv_3 = Conv2D(filters = nb_filters3, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_3')(pool_2)
    pool_3 = MaxPooling2D(pool_size_1)(conv_3)
    
    
    conv_4 = Conv2D(filters = nb_filters4, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_4')(pool_3)
    pool_4 = MaxPooling2D(pool_size_2)(conv_4)
    
    
    conv_5 = Conv2D(filters = nb_filters5, kernel_size = ksize, strides=1,
                      padding= 'valid', activation='relu', name='conv_5')(pool_4)
    pool_5 = MaxPooling2D(pool_size_2)(conv_5)

    flatten1 = Flatten()(pool_5)
    ### Recurrent Block
    
    # Pooling layer
    pool_lstm1 = MaxPooling2D(pool_size_3, name = 'pool_lstm')(layer)
    
    # Embedding layer

    squeezed = Lambda(lambda x: K.squeeze(x, axis= -1))(pool_lstm1)
#     flatten2 = K.squeeze(pool_lstm1, axis = -1)
#     dense1 = Dense(dense_size1)(flatten)
    
    # Bidirectional GRU
    lstm = Bidirectional(GRU(lstm_count))(squeezed)  #default merge mode is concat
    
    # Concat Output
    concat = concatenate([flatten1, lstm], axis=-1, name ='concat')
    
    ## Softmax Output
    output = Dense(num_classes, activation = 'softmax', name='preds')(concat)
    
    model_output = output
    model = Model(model_input, model_output)
    
#     opt = Adam(lr=0.001)
    opt = RMSprop(lr=0.0005)  # Optimizer
    model.compile(
            loss='sparse_categorical_crossentropy',
            optimizer=opt,
            metrics=['accuracy']
        )
    
    print(model.summary())
    return model

# %%
def train_model(x_train, y_train, x_val, y_val):
    
    n_frequency = 128
    n_frames = 640
    #reshape and expand dims for conv2d
#     x_train = x_train.reshape(-1, n_frequency, n_frames)
    x_train = np.expand_dims(x_train, axis = -1)
#     y_train = np.expand_dims(y_train, axis = -1)
    
#     x_val = x_val.reshape(-1, n_frequency, n_frames)
    x_val = np.expand_dims(x_val, axis = -1)
#     y_val = np.expand_dims(y_val, axis = -1)
    
    input_shape = (n_frames, n_frequency, 1)
    model_input = Input(input_shape, name='input')
    
    model = conv_recurrent_model_build(model_input)
    
#     tb_callback = TensorBoard(log_dir='./logs/4', histogram_freq=1, batch_size=32, write_graph=True, write_grads=False,
#                               write_images=False, embeddings_freq=0, embeddings_layer_names=None,
#                               embeddings_metadata=None)
    checkpoint_callback = ModelCheckpoint('./models/parallel/weights.best.h5', monitor='val_acc', verbose=1,
                                          save_best_only=True, mode='max')
    
    reducelr_callback = ReduceLROnPlateau(
                monitor='val_acc', factor=0.5, patience=10, min_delta=0.01,
                verbose=1
            )
    callbacks_list = [checkpoint_callback, reducelr_callback]

    # Fit the model and get training history.
    print('Training...')
    history = model.fit(x_train, y_train,epochs=EPOCH_COUNT,
                        validation_data=(x_val, y_val),
                        verbose=1,
                        callbacks=callbacks_list
                       )

    return model, history

# %%
def show_summary_stats(history):
    # List all data in history
    print(history.history.keys())

    # Summarize history for accuracy
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

    # Summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
print(X_train.shape,y_train.shape)
print(X_valid.shape,y_valid.shape)
# Out:
# (6394, 640, 128) (6394,)
# (800, 640, 128) (800,)

# %%
model, history  = train_model(X_train, y_train, X_valid, y_valid)
# Out:
# Building model...
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              (None, 640, 128, 1)  0
# __________________________________________________________________________________________________
# conv_1 (Conv2D)                 (None, 638, 128, 16) 64          input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 319, 64, 16)  0           conv_1[0][0]
# __________________________________________________________________________________________________
# conv_2 (Conv2D)                 (None, 317, 64, 32)  1568        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 158, 32, 32)  0           conv_2[0][0]
# __________________________________________________________________________________________________
# conv_3 (Conv2D)                 (None, 156, 32, 64)  6208        max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 78, 16, 64)   0           conv_3[0][0]
# __________________________________________________________________________________________________
# conv_4 (Conv2D)                 (None, 76, 16, 64)   12352       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 19, 4, 64)    0           conv_4[0][0]
# __________________________________________________________________________________________________
# conv_5 (Conv2D)                 (None, 17, 4, 64)    12352       max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# pool_lstm (MaxPooling2D)        (None, 160, 64, 1)   0           input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 4, 1, 64)     0           conv_5[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 160, 64)      0           pool_lstm[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 256)          0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 128)          49536       lambda_3[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 384)          0           flatten_3[0][0]
#                                                                  bidirectional_3[0][0]
# __________________________________________________________________________________________________
# preds (Dense)                   (None, 8)            3080        concat[0][0]
# ==================================================================================================
# Total params: 85,160
# Trainable params: 85,160
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Training...
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 6394 samples, validate on 800 samples
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\bmp09\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 6394/6394 [==============================] - 213s 33ms/step - loss: 1.9414 - acc: 0.2609 - val_loss: 1.8122 - val_acc: 0.3425
#
# Epoch 00001: val_acc improved from -inf to 0.34250, saving model to ./models/parallel/weights.best.h5
# Epoch 2/50
# 6394/6394 [==============================] - 207s 32ms/step - loss: 1.7769 - acc: 0.3394 - val_loss: 1.7455 - val_acc: 0.3438
#
# Epoch 00002: val_acc improved from 0.34250 to 0.34375, saving model to ./models/parallel/weights.best.h5
# Epoch 3/50
# 6394/6394 [==============================] - 207s 32ms/step - loss: 1.6966 - acc: 0.3815 - val_loss: 1.6584 - val_acc: 0.4163
#
# Epoch 00003: val_acc improved from 0.34375 to 0.41625, saving model to ./models/parallel/weights.best.h5
# Epoch 4/50
# 6394/6394 [==============================] - 209s 33ms/step - loss: 1.6479 - acc: 0.3946 - val_loss: 1.6233 - val_acc: 0.3787
#
# Epoch 00004: val_acc did not improve from 0.41625
# Epoch 5/50
# 6394/6394 [==============================] - 205s 32ms/step - loss: 1.6042 - acc: 0.4174 - val_loss: 1.5935 - val_acc: 0.4213
#
# Epoch 00005: val_acc improved from 0.41625 to 0.42125, saving model to ./models/parallel/weights.best.h5
# Epoch 6/50
# 6394/6394 [==============================] - 207s 32ms/step - loss: 1.5669 - acc: 0.4370 - val_loss: 1.5797 - val_acc: 0.4425
#
# Epoch 00006: val_acc improved from 0.42125 to 0.44250, saving model to ./models/parallel/weights.best.h5
# Epoch 7/50
# 6394/6394 [==============================] - 189s 30ms/step - loss: 1.5388 - acc: 0.4525 - val_loss: 1.6301 - val_acc: 0.3875
#
# Epoch 00007: val_acc did not improve from 0.44250
# Epoch 8/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 1.5130 - acc: 0.4600 - val_loss: 1.6098 - val_acc: 0.4238
#
# Epoch 00008: val_acc did not improve from 0.44250
# Epoch 9/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 1.4965 - acc: 0.4664 - val_loss: 1.6275 - val_acc: 0.3787
#
# Epoch 00009: val_acc did not improve from 0.44250
# Epoch 10/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 1.4674 - acc: 0.4850 - val_loss: 1.6311 - val_acc: 0.3912
#
# Epoch 00010: val_acc did not improve from 0.44250
# Epoch 11/50
# 6394/6394 [==============================] - 115s 18ms/step - loss: 1.4474 - acc: 0.4884 - val_loss: 1.5906 - val_acc: 0.4150
# Epoch 00011: val_acc did not improve from 0.44250
# Epoch 12/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 1.4261 - acc: 0.4952 - val_loss: 1.5458 - val_acc: 0.4325
#
# Epoch 00012: val_acc did not improve from 0.44250
# Epoch 13/50
# 6394/6394 [==============================] - 122s 19ms/step - loss: 1.4113 - acc: 0.4978 - val_loss: 1.4951 - val_acc: 0.4487
#
# Epoch 00013: val_acc improved from 0.44250 to 0.44875, saving model to ./models/parallel/weights.best.h5
# Epoch 14/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 1.3955 - acc: 0.5142 - val_loss: 1.5721 - val_acc: 0.4313
#
# Epoch 00014: val_acc did not improve from 0.44875
# Epoch 15/50
# 6394/6394 [==============================] - 127s 20ms/step - loss: 1.3756 - acc: 0.5170 - val_loss: 1.5783 - val_acc: 0.4387
#
# Epoch 00015: val_acc did not improve from 0.44875
# Epoch 16/50
# 6394/6394 [==============================] - 124s 19ms/step - loss: 1.3539 - acc: 0.5267 - val_loss: 1.4823 - val_acc: 0.4562
#
# Epoch 00016: val_acc improved from 0.44875 to 0.45625, saving model to ./models/parallel/weights.best.h5
# Epoch 17/50
# 6394/6394 [==============================] - 130s 20ms/step - loss: 1.3373 - acc: 0.5338 - val_loss: 1.5042 - val_acc: 0.4725
#
# Epoch 00017: val_acc improved from 0.45625 to 0.47250, saving model to ./models/parallel/weights.best.h5
# Epoch 18/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 1.3218 - acc: 0.5404 - val_loss: 1.5392 - val_acc: 0.4688
#
# Epoch 00018: val_acc did not improve from 0.47250
# Epoch 19/50
# 6394/6394 [==============================] - 118s 19ms/step - loss: 1.3034 - acc: 0.5441 - val_loss: 1.5943 - val_acc: 0.4150
#
# Epoch 00019: val_acc did not improve from 0.47250
# Epoch 20/50
# 6394/6394 [==============================] - 122s 19ms/step - loss: 1.2897 - acc: 0.5494 - val_loss: 1.5400 - val_acc: 0.4400
#
# Epoch 00020: val_acc did not improve from 0.47250
# Epoch 21/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 1.2760 - acc: 0.5574 - val_loss: 1.4819 - val_acc: 0.4650
#
# Epoch 00021: val_acc did not improve from 0.47250
# Epoch 22/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 1.2572 - acc: 0.5571 - val_loss: 1.5574 - val_acc: 0.4450
#
# Epoch 00022: val_acc did not improve from 0.47250
# Epoch 23/50
# 6394/6394 [==============================] - 122s 19ms/step - loss: 1.2362 - acc: 0.5671 - val_loss: 1.4646 - val_acc: 0.4775
#
# Epoch 00023: val_acc improved from 0.47250 to 0.47750, saving model to ./models/parallel/weights.best.h5
# Epoch 24/50
# 6394/6394 [==============================] - 133s 21ms/step - loss: 1.2271 - acc: 0.5668 - val_loss: 1.4860 - val_acc: 0.4662
#
# Epoch 00024: val_acc did not improve from 0.47750
# Epoch 25/50
# 6394/6394 [==============================] - 125s 20ms/step - loss: 1.2045 - acc: 0.5865 - val_loss: 1.6033 - val_acc: 0.4500
#
# Epoch 00025: val_acc did not improve from 0.47750
# Epoch 26/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 1.1958 - acc: 0.5818 - val_loss: 1.4710 - val_acc: 0.4637
#
# Epoch 00026: val_acc did not improve from 0.47750
# Epoch 27/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 1.1719 - acc: 0.5913 - val_loss: 1.5742 - val_acc: 0.4575
#
# Epoch 00027: val_acc did not improve from 0.47750
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 28/50
# 6394/6394 [==============================] - 124s 19ms/step - loss: 1.0753 - acc: 0.6292 - val_loss: 1.5155 - val_acc: 0.4637
#
# Epoch 00028: val_acc did not improve from 0.47750
# Epoch 29/50
# 6394/6394 [==============================] - 126s 20ms/step - loss: 1.0625 - acc: 0.6389 - val_loss: 1.5006 - val_acc: 0.4613
#
# Epoch 00029: val_acc did not improve from 0.47750
# Epoch 30/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 1.0456 - acc: 0.6472 - val_loss: 1.4742 - val_acc: 0.4888
#
# Epoch 00030: val_acc improved from 0.47750 to 0.48875, saving model to ./models/parallel/weights.best.h5
# Epoch 31/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 1.0371 - acc: 0.6473 - val_loss: 1.5184 - val_acc: 0.4988
#
# Epoch 00031: val_acc improved from 0.48875 to 0.49875, saving model to ./models/parallel/weights.best.h5
# Epoch 32/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 1.0219 - acc: 0.6545 - val_loss: 1.5003 - val_acc: 0.4888
#
# Epoch 00032: val_acc did not improve from 0.49875
# Epoch 33/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 1.0099 - acc: 0.6587 - val_loss: 1.5162 - val_acc: 0.4875
#
# Epoch 00033: val_acc did not improve from 0.49875
# Epoch 34/50
# 6394/6394 [==============================] - 136s 21ms/step - loss: 0.9988 - acc: 0.6655 - val_loss: 1.5113 - val_acc: 0.4988
#
# Epoch 00034: val_acc did not improve from 0.49875
# Epoch 35/50
# 6394/6394 [==============================] - 126s 20ms/step - loss: 0.9839 - acc: 0.6738 - val_loss: 1.5291 - val_acc: 0.4888
#
# Epoch 00035: val_acc did not improve from 0.49875
# Epoch 36/50
# 6394/6394 [==============================] - 126s 20ms/step - loss: 0.9716 - acc: 0.6711 - val_loss: 1.5506 - val_acc: 0.4662
#
# Epoch 00036: val_acc did not improve from 0.49875
# Epoch 37/50
# 6394/6394 [==============================] - 134s 21ms/step - loss: 0.9625 - acc: 0.6770 - val_loss: 1.5689 - val_acc: 0.4487
#
# Epoch 00037: val_acc did not improve from 0.49875
# Epoch 38/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 0.9498 - acc: 0.6814 - val_loss: 1.5473 - val_acc: 0.4888
#
# Epoch 00038: val_acc did not improve from 0.49875
# Epoch 39/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 0.9368 - acc: 0.6778 - val_loss: 1.5696 - val_acc: 0.4775
#
# Epoch 00039: val_acc did not improve from 0.49875
# Epoch 40/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 0.9193 - acc: 0.6866 - val_loss: 1.5485 - val_acc: 0.4800
#
# Epoch 00040: val_acc did not improve from 0.49875
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 41/50
# 6394/6394 [==============================] - 120s 19ms/step - loss: 0.8707 - acc: 0.7100 - val_loss: 1.5374 - val_acc: 0.4688
#
# Epoch 00041: val_acc did not improve from 0.49875
# Epoch 42/50
# 6394/6394 [==============================] - 121s 19ms/step - loss: 0.8588 - acc: 0.7196 - val_loss: 1.5261 - val_acc: 0.4762
#
# Epoch 00042: val_acc did not improve from 0.49875
# Epoch 43/50
# 6394/6394 [==============================] - 128s 20ms/step - loss: 0.8503 - acc: 0.7186 - val_loss: 1.5690 - val_acc: 0.4675
#
# Epoch 00043: val_acc did not improve from 0.49875
# Epoch 44/50
# 6394/6394 [==============================] - 125s 19ms/step - loss: 0.8432 - acc: 0.7183 - val_loss: 1.5651 - val_acc: 0.4800
#
# Epoch 00044: val_acc did not improve from 0.49875
# Epoch 45/50
# 6394/6394 [==============================] - 155s 24ms/step - loss: 0.8338 - acc: 0.7261 - val_loss: 1.5643 - val_acc: 0.4800
#
# Epoch 00045: val_acc did not improve from 0.49875
# Epoch 46/50
# 6394/6394 [==============================] - 136s 21ms/step - loss: 0.8289 - acc: 0.7316 - val_loss: 1.5507 - val_acc: 0.4613
#
# Epoch 00046: val_acc did not improve from 0.49875
# Epoch 47/50
# 6394/6394 [==============================] - 132s 21ms/step - loss: 0.8200 - acc: 0.7315 - val_loss: 1.5882 - val_acc: 0.4600
#
# Epoch 00047: val_acc did not improve from 0.49875
# Epoch 48/50
# 6394/6394 [==============================] - 127s 20ms/step - loss: 0.8102 - acc: 0.7346 - val_loss: 1.5505 - val_acc: 0.4838
#
# Epoch 00048: val_acc did not improve from 0.49875
# Epoch 49/50
# 6394/6394 [==============================] - 123s 19ms/step - loss: 0.8079 - acc: 0.7319 - val_loss: 1.5595 - val_acc: 0.4900
#
# Epoch 00049: val_acc did not improve from 0.49875
# Epoch 50/50
# 6394/6394 [==============================] - 126s 20ms/step - loss: 0.7986 - acc: 0.7371 - val_loss: 1.5558 - val_acc: 0.4725
#
# Epoch 00050: val_acc did not improve from 0.49875
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.

# %%
show_summary_stats(history)
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc', 'lr'])

# %%
print(y_pred.shape)
# Out:
# (800,)

# %%
from sklearn.metrics import classification_report

y_true = y_valid
print(y_true)
X_test_val = np.expand_dims(X_valid, axis = -1)
y_pred_1 = model.predict(X_test_val)
print("y_pred_1")
print(y_pred_1)
y_pred_2 = np.argmax(y_pred_1, axis=1)

print("y_pred_2")
print(y_pred_2)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred_2, target_names=target_names))
# Out:
# [6 7 5 2 6 0 2 1 6 6 1 4 7 1 0 3 2 7 5 6 1 7 0 1 4 0 7 5 3 3 4 5 6 2 3 4 1
#  0 1 6 0 6 2 4 4 2 7 6 5 2 2 1 0 0 6 2 3 2 0 4 5 5 0 5 0 1 5 5 6 6 7 7 7 4
#  6 1 3 2 5 6 7 5 3 4 3 5 2 0 1 2 6 7 4 7 2 2 0 1 4 0 1 4 6 5 5 3 0 6 1 7 4
#  7 4 2 6 3 1 0 1 3 1 4 4 7 1 1 5 1 3 4 5 7 3 2 5 6 6 5 7 4 5 4 5 7 4 4 6 0
#  4 7 7 5 6 1 4 2 7 5 4 4 2 5 1 1 7 5 4 3 7 3 7 1 3 7 0 3 7 0 3 0 7 2 3 4 1
#  2 5 4 6 7 6 2 2 4 5 0 5 7 3 2 4 5 6 6 2 4 6 1 2 0 0 7 7 4 3 6 4 5 7 0 2 5
#  0 7 7 5 6 7 6 4 2 3 7 0 6 0 5 1 4 1 7 5 4 6 0 6 2 5 3 0 1 7 4 0 2 5 7 3 5
#  1 3 6 1 6 3 0 5 5 7 4 6 5 2 5 3 3 2 5 0 6 6 1 1 1 2 5 6 0 3 7 2 2 7 0 1 1
#  6 6 5 3 5 0 0 1 3 4 5 3 3 3 4 2 0 3 2 0 4 3 4 2 6 1 6 2 4 2 5 5 1 5 4 1 5
#  1 0 6 7 3 1 1 5 1 3 3 3 6 7 1 4 5 1 3 4 7 2 1 0 0 6 1 7 6 3 1 6 7 2 4 7 2
#  0 1 5 1 0 0 3 7 3 7 6 0 4 1 6 2 3 2 6 0 6 3 1 3 5 2 5 7 4 2 5 7 5 7 0 5 4
#  2 5 7 1 0 7 6 0 4 4 6 3 4 6 4 6 4 2 6 1 6 5 7 5 2 4 6 4 1 5 7 0 4 0 5 3 3
#  2 3 2 5 7 5 2 5 3 4 7 1 1 0 7 4 6 4 1 4 2 5 3 6 0 4 4 1 0 3 3 7 3 1 6 7 5
#  3 6 0 6 3 4 5 0 6 6 3 7 1 4 4 6 0 5 5 3 4 5 3 0 7 2 4 3 6 1 5 3 0 6 0 6 3
#  1 2 0 6 2 6 7 7 1 7 0 2 1 6 2 6 1 5 6 5 7 6 0 7 2 5 0 0 2 4 4 7 4 5 5 1 3
#  1 5 2 2 1 6 0 2 1 4 4 4 2 6 5 1 2 3 0 7 4 7 1 3 0 4 2 1 3 4 2 7 2 3 3 0 3
#  3 3 0 1 0 0 3 3 1 6 6 6 6 1 6 3 3 6 0 1 3 3 1 1 1 2 2 6 3 5 7 4 3 3 2 7 6
#  0 0 5 0 3 7 3 2 4 5 1 5 6 3 1 0 0 3 1 4 1 6 0 2 0 3 2 2 5 7 3 0 1 2 2 0 7
#  7 0 1 7 7 5 2 5 2 6 5 2 1 6 4 2 0 2 7 0 4 1 7 7 2 0 3 4 3 7 5 7 0 5 1 1 1
#  7 2 2 7 6 4 4 7 2 7 0 4 5 2 7 1 7 6 6 0 4 3 5 5 3 5 3 4 4 0 3 4 3 1 2 6 5
#  7 7 5 5 7 2 0 4 0 7 4 5 6 6 4 6 0 1 2 2 2 7 4 4 2 0 1 0 1 1 6 4 0 3 1 5 3
#  2 6 6 2 2 4 1 5 3 3 2 2 4 4 0 7 3 2 0 0 7 0 7]
# y_pred_1
# [[5.1306859e-02 6.2121326e-01 4.4847708e-02 ... 7.7314816e-02
#   5.9394736e-02 1.1280987e-01]
#  [4.9408129e-04 3.1522971e-02 1.4823473e-02 ... 3.2247982e-03
#   3.4994941e-02 9.1166925e-01]
#  [1.2773736e-02 5.9484012e-02 3.6860861e-02 ... 8.1464267e-01
#   6.6203304e-02 1.3269035e-03]
#  ...
#  [1.6077015e-01 9.0704054e-02 1.6838101e-03 ... 2.3483487e-02
#   7.4503988e-02 4.5186436e-01]
#  [8.2562864e-01 5.8268351e-03 8.4165327e-04 ... 1.8126881e-03
#   5.5349041e-03 6.3184314e-05]
#  [1.0529879e-02 2.7605629e-02 2.1195668e-01 ... 2.1142796e-01
#   2.4966568e-01 6.7342632e-02]]
# y_pred_2
# [1 7 5 6 1 1 6 1 7 5 1 1 7 1 6 5 5 7 1 0 1 6 5 7 1 0 7 5 0 6 1 0 1 2 0 4 4
#  6 1 3 0 7 6 2 4 2 3 0 3 2 2 1 3 0 5 2 3 2 0 0 5 3 0 3 1 1 1 5 1 6 7 7 7 5
#  1 0 0 5 0 6 3 1 3 6 3 6 2 5 1 6 0 7 1 1 2 6 0 4 0 1 1 4 3 5 0 6 0 2 3 6 6
#  7 4 2 1 3 1 3 0 0 1 0 4 7 4 4 5 0 3 4 3 6 3 2 5 1 0 0 7 6 6 1 0 7 1 1 3 0
#  1 7 1 2 5 1 2 2 7 5 4 7 2 5 2 4 7 5 1 3 7 1 7 1 1 3 6 5 7 0 3 4 7 2 3 4 1
#  2 5 2 7 5 6 2 2 2 0 1 3 7 3 2 0 1 1 5 2 6 6 0 2 0 0 7 7 6 0 7 6 7 1 4 2 6
#  3 0 6 0 1 7 7 4 2 3 0 6 6 0 5 0 4 3 7 5 4 1 3 1 2 5 3 0 1 7 6 6 2 6 7 3 2
#  4 3 6 1 4 3 3 5 5 6 4 3 7 6 5 3 3 2 1 3 1 7 1 1 7 6 2 1 0 3 1 2 2 4 0 6 1
#  7 7 6 3 5 1 0 1 3 2 5 3 0 3 7 2 0 5 2 5 2 2 6 7 6 1 1 6 2 2 2 5 1 1 6 1 5
#  1 0 5 7 3 7 7 1 1 6 3 0 4 3 1 4 5 1 0 6 7 6 1 0 1 3 2 7 1 3 4 4 6 2 5 7 2
#  0 4 6 1 1 7 6 7 3 7 4 1 4 1 4 2 0 2 3 3 3 5 1 0 0 6 1 6 1 2 5 7 5 7 0 5 1
#  2 0 7 1 3 7 7 0 0 7 2 5 1 6 4 0 1 2 2 7 0 2 7 3 6 4 6 4 1 1 7 0 4 0 5 7 0
#  6 6 6 5 7 5 2 5 3 6 7 1 1 0 7 6 1 7 1 4 5 5 1 1 1 1 5 1 2 3 6 7 3 2 7 7 5
#  3 0 0 1 3 7 5 1 5 0 3 7 3 7 6 0 0 5 1 3 7 5 3 1 2 2 1 3 0 3 5 0 0 3 0 0 3
#  1 2 3 3 6 1 7 0 1 7 0 2 1 7 1 1 1 5 0 5 7 5 0 0 4 2 1 6 6 6 7 0 6 0 5 4 1
#  0 5 2 2 7 4 0 2 0 1 0 4 6 0 5 1 2 3 0 7 2 7 7 5 1 1 2 0 0 4 6 6 4 0 3 1 5
#  3 3 0 1 5 3 6 0 1 5 1 5 0 1 5 3 0 1 3 0 3 5 1 4 7 2 7 2 3 5 7 4 0 0 7 7 0
#  0 4 6 1 0 2 5 6 1 5 7 5 3 3 4 4 4 3 1 4 0 6 6 2 1 3 2 2 5 1 2 3 7 2 2 0 7
#  7 0 1 7 2 5 6 3 2 4 4 2 0 0 0 2 0 7 7 1 6 1 6 7 5 0 6 6 3 7 5 7 0 5 1 4 7
#  6 2 6 7 7 4 2 7 2 7 3 4 2 2 6 1 7 0 7 4 5 3 1 5 0 4 0 1 2 0 6 4 3 1 2 2 5
#  2 7 5 4 7 6 3 4 4 4 2 5 3 6 2 1 3 5 2 2 7 6 7 7 3 0 1 0 5 0 7 1 3 3 1 5 3
#  5 0 6 2 2 4 1 0 3 0 2 2 4 4 0 1 0 2 0 0 7 0 6]
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.38      0.47      0.42       100
#  Experimental       0.40      0.55      0.46       100
#          Folk       0.66      0.65      0.65       100
#       Hip-Hop       0.55      0.52      0.53       100
#  Instrumental       0.48      0.30      0.37       100
# International       0.60      0.52      0.56       100
#           Pop       0.14      0.12      0.13       100
#          Rock       0.60      0.65      0.62       100
#
#      accuracy                           0.47       800
#     macro avg       0.47      0.47      0.47       800
#  weighted avg       0.47      0.47      0.47       800

# %%
from sklearn.metrics import accuracy_score

print(accuracy_score(y_true, y_pred))
# Out:
# 0.4725

# %%
npzfile = np.load('test_arr.npz')
print(npzfile.files)
X_test = npzfile['arr_0']
y_test = npzfile['arr_1']
print(X_test.shape, y_test.shape)
# Out:
# ['arr_0', 'arr_1']
# (800, 640, 128) (800,)

# %%
from keras.models import load_model

weights_path = 'models/parallel/weights.best.h5'
model = load_model(weights_path)

# %%
y_test -= 1
print(np.amin(y_test), np.amax(y_test), np.mean(y_test))
# Out:
# 0 7 3.5

# %%
X_test_raw = librosa.core.db_to_power(X_test, ref=1.0)
print(np.amin(X_test_raw), np.amax(X_test_raw), np.mean(X_test_raw))
# Out:
# 1e-08 1.0 0.004623813018385694

# %%
X_test = np.log(X_test_raw)


from sklearn.metrics import classification_report

y_true = y_test
X_test = np.expand_dims(X_test, axis = -1)
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=1)
labels = [0,1,2,3,4,5,6,7]
target_names = dict_genres.keys()

print(y_true.shape, y_pred.shape)
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# (800,) (800,)
#                precision    recall  f1-score   support
#
#    Electronic       0.58      0.34      0.43       100
#  Experimental       0.23      0.24      0.24       100
#          Folk       0.25      0.25      0.25       100
#       Hip-Hop       0.45      0.86      0.59       100
#  Instrumental       0.33      0.40      0.36       100
# International       0.47      0.40      0.43       100
#           Pop       0.26      0.10      0.14       100
#          Rock       0.55      0.53      0.54       100
#
#      accuracy                           0.39       800
#     macro avg       0.39      0.39      0.37       800
#  weighted avg       0.39      0.39      0.37       800

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

f, ax = plt.subplots(figsize=(9, 6))

mat = confusion_matrix(y_true, y_pred)
sns.heatmap(mat.T, square=True, annot=True, fmt='d', cbar=False,ax =ax,
            xticklabels=dict_genres.keys(),
            yticklabels=dict_genres.keys())



plt.xlabel('true label')
plt.ylabel('predicted label');

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_true, y_pred))
# Out:
# 0.39
